# %% [markdown]
# # AgriYield Predictor – Introduction & Project Scope

# %% [markdown]
# **`Title:` AgriYield Predictor: Forecasting Crop Yield Using Environmental and Soil Data**

# %% [markdown]
# **`Objective:`**
#
# To develop a machine learning system that predicts crop yield based on tabular environmental
# and soil parameters such as rainfall, temperature, humidity, soil type, and nutrient content. The
# project aims to assist farmers and agricultural planners in optimizing crop production.

# %% [markdown]
# **`Outcomes:`**
#
# • Understand preprocessing and feature engineering on tabular agricultural datasets.
#
# • Learn to train and evaluate regression models for yield prediction.
#
# • Gain experience in model performance comparison and explainability (e.g., SHAP
# values).
#
# • Deliver a functional prototype with yield predictions based on user input or uploaded
# data.

# %% [markdown]
# **`Dataset:`**
#
# • FAO Crop Production Dataset: Contains crop yield data from different regions.
#
#
#
#
# Link: https://www.fao.org/faostat/en/#data/QCL
#
# • Kaggle or Indian Government Open Agriculture Data Portal: Includes environmental
# and soil data by region.
#
# Link1: https://www.kaggle.com/datasets/atharvaingle/crop-recommendation-dataset
#
# Link2: https://www.data.gov.in/sector/agriculture
#
# • Weather and Soil Data from publicly available sources like Kaggle, NOAA, or Open
# Weather Map historical APIs.
#
# Link: https://www.kaggle.com/datasets/sobhanmoosavi/us-weather-events
#
# Link: https://www.ncei.noaa.gov/

# %% [markdown]
# **`Architectural diagram: `**
#
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **`Modules to be Implemented:`**
#
# 1. Data Collection & Preprocessing
# 2. Exploratory Data Analysis (EDA) & Feature Engineering
# 3. Machine Learning Model Development
# 4. UI for Data Input and Prediction Output
# 5. Evaluation and Final Deployment

# %% [markdown]
# **`Tools & Tech Stack`**
#
# To implement the AgriYield Predictor project effectively, consider the following tools and
# technologies:
#
#
#
# > Programming Language
#
#
# • Python: Widely used for data analysis and machine learning tasks.
#
# > Libraries & Frameworks
#
# • Data Handling: pandas, numpy
#
# • Visualization: matplotlib, seaborn, plotly
#
# • Machine Learning: scikit-learn, xgboost, lightgbm
#
# • Model Interpretation: SHAP, eli5
#
# • Web Framework: Flask or Django for developing the web interface
#
# • Frontend: HTML, CSS, JavaScript, possibly with Bootstrap for responsive design
#
# > Development Tools
#
# • IDE: Jupyter Notebook, VS Code
#
# • Version Control: Git with platforms like GitHub or GitLab
#
# • Deployment: Heroku, AWS, or Google Cloud Platform for hosting the application

# %% [markdown]
# # Machine Learning Pipeline – Step-by-Step Workflow

# %% [markdown]
# Step 1: Collection of Datasets
#
# Collect datasets from FAO, Kaggle, NOAA, ICRISAT, etc.
#
# ---
#
#
#
# Step 2: Exploratory Data Analysis (EDA)
# * Combining Datasets
# * Checking nulls
#
#
#
#
# * Checking duplicates
#
# * Checking outliers
#
# * Checking distributions
#
# * Checking bias
#
#
#
#
# ---
#
#
# Step 3: Feature Engineering
#
# * Extracting useful columns
# * (Correlation matrix,...)
# * Converting categorical → numerical
#
# * Standardizing / Normalizing data
#
# * (-1 to 1 or 0 to 1)... Standard Scaler / Min Max Scaler
#
#
# ---
#
#
# Step 4: Splitting Dataset into Train & Test
#
# `(x_train, x_test, y_train, y_test)`
#
#
#
#
#
#
# ---
#
#
# Step 5: Selecting Suitable Model
#
# Choose best ML algorithms (LR, DT, RF, XGBoost, etc.)
#
#
# ---
#
#
# Step 6: Model Training(x_train, x_test)
#
# Train the selected model using training data.
#
#
# ---
#
#
# Step 7: Predicting Results
#
# Generate predictions using test data:
# `y_pred = model.predict(x_test)`
#
#
# ---
#
#
# Step 8: Evaluating Model Accuracy(Y-pred,y_test)
#
# Compare predictions vs actual:
#
# * R² Score
#
# * MAE
#
# * RMSE
#
#
# ---
#
#
# Step 9: Hyperparameter Tuning
#
# Use GridSearchCV / RandomizedSearchCV to improve model.
#
#
# ---
#
#
# Step 10: Retraining the Model with data(x_train,y_train)
#
# Train model again using best parameters.
#
#
# ---
#
#
# Step 11: Predicting Results (x_test)...y_pred
#
# Run predictions again after tuning.
#
#
# ---
#
#
# Step 12: Evaluating Model Accuracy (Y-pred,y_test)
#
# Check improved metrics using tuned model.
#
#
# ---
#
#
# Step 13: Deployment
#
# Deploy the final model using Flask / Django / Streamlit and host it on cloud.

# %% [markdown]
# # Milestone 1: Week 1 & 2 - Requirements & Dataset Preparation

# %% [markdown]
# • Define project scope and success metrics.
#
# • Collect and clean crop yield, weather, and soil datasets.
#
# • Merge datasets based on geolocation and crop type.
#
# • Handle missing values, normalize/standardize features.

# %%
import pandas as pd
fao = pd.read_csv("/content/FAOSTAT_data_en_12-8-2025.csv")
crop = pd.read_csv("/content/Crop_recommendation.csv")

# %% [markdown]
# ## FAO Dataset Details

# %%
fao
# Out:
#      Domain Code                        Domain  Area Code (M49)   Area  \
# 0            QCL  Crops and livestock products              356  India
# 1            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# 3            QCL  Crops and livestock products              356  India
# 4            QCL  Crops and livestock products              356  India
# ...          ...                           ...              ...    ...
# 5935         QCL  Crops and livestock products              356  India
# 5936         QCL  Crops and livestock products              356  India
# 5937         QCL  Crops and livestock products              356  India
# 5938         QCL  Crops and livestock products              356  India
# 5939         QCL  Crops and livestock products              356  India
#
#       Element Code         Element  Item Code (CPC)  \
# 0             5312  Area harvested           1654.0
# 1             5412           Yield           1654.0
# 2             5510      Production           1654.0
# 3             5312  Area harvested           1654.0
# 4             5412           Yield           1654.0
# ...            ...             ...              ...
# 5935          5412           Yield            111.0
# 5936          5510      Production            111.0
# 5937          5312  Area harvested            111.0
# 5938          5412           Yield            111.0
# 5939          5510      Production            111.0
#
#                                                    Item  Year Code  Year  \
# 0     Anise, badian, coriander, cumin, caraway, fenn...       2000  2000
# 1     Anise, badian, coriander, cumin, caraway, fenn...       2000  2000
# 2     Anise, badian, coriander, cumin, caraway, fenn...       2000  2000
# 3     Anise, badian, coriander, cumin, caraway, fenn...       2001  2001
# 4     Anise, badian, coriander, cumin, caraway, fenn...       2001  2001
# ...                                                 ...        ...   ...
# 5935                                              Wheat       2022  2022
# 5936                                              Wheat       2022  2022
# 5937                                              Wheat       2023  2023
# 5938                                              Wheat       2023  2023
# 5939                                              Wheat       2023  2023
#
#        Unit         Value Flag Flag Description Note
# 0        ha  3.444340e+05    A  Official figure  NaN
# 1     kg/ha  4.840000e+02    A  Official figure  NaN
# 2         t  1.666920e+05    A  Official figure  NaN
# 3        ha  5.692710e+05    A  Official figure  NaN
# 4     kg/ha  4.303000e+02    A  Official figure  NaN
# ...     ...           ...  ...              ...  ...
# 5935  kg/ha  3.537300e+03    A  Official figure  NaN
# 5936      t  1.077421e+08    A  Official figure  NaN
# 5937     ha  3.140072e+07    A  Official figure  NaN
# 5938  kg/ha  3.520700e+03    A  Official figure  NaN
# 5939      t  1.105537e+08    A  Official figure  NaN
#
# [5940 rows x 15 columns]

# %%
fao['Item'].unique()
# Out:
# array(['Anise, badian, coriander, cumin, caraway, fennel and juniper berries, raw',
#        'Apples', 'Apricots', 'Areca nuts', 'Bananas', 'Barley',
#        'Beans, dry', 'Cabbages', 'Cantaloupes and other melons',
#        'Carrots and turnips', 'Cashew nuts, in shell', 'Cassava, fresh',
#        'Castor oil seeds', 'Cauliflowers and broccoli', 'Cherries',
#        'Chick peas, dry',
#        'Chillies and peppers, dry (Capsicum spp., Pimenta spp.), raw',
#        'Chillies and peppers, green (Capsicum spp. and Pimenta spp.)',
#        'Cocoa beans', 'Coconuts, in shell', 'Coffee, green', 'Coir, raw',
#        'Cucumbers and gherkins', 'Eggplants (aubergines)', 'Figs',
#        'Ginger, raw', 'Grapes', 'Green garlic',
#        'Groundnuts, excluding shelled', 'Jute, raw or retted',
#        'Kenaf, and other textile bast fibres, raw or retted',
#        'Lemons and limes', 'Lentils, dry', 'Lettuce and chicory',
#        'Linseed', 'Maize (corn)', 'Mangoes, guavas and mangosteens',
#        'Millet', 'Mushrooms and truffles',
#        'Natural rubber in primary forms', 'Nutmeg, mace, cardamoms, raw',
#        'Okra', 'Onions and shallots, dry (excluding dehydrated)',
#        'Oranges', 'Other beans, green',
#        'Other berries and fruits of the genus vaccinium n.e.c.',
#        'Other citrus fruit, n.e.c.', 'Other fruits, n.e.c.',
#        'Other oil seeds, n.e.c.', 'Other pulses n.e.c.',
#        'Other stimulant, spice and aromatic crops, n.e.c.',
#        'Other stone fruits', 'Other tropical fruits, n.e.c.',
#        'Other vegetables, fresh n.e.c.', 'Papayas',
#        'Peaches and nectarines', 'Pears', 'Peas, dry', 'Peas, green',
#        'Pepper (Piper spp.), raw', 'Pigeon peas, dry', 'Pineapples',
#        'Plums and sloes', 'Pomelos and grapefruits', 'Poppy seed',
#        'Potatoes', 'Pumpkins, squash and gourds', 'Rape or colza seed',
#        'Rice', 'Safflower seed', 'Seed cotton, unginned', 'Sesame seed',
#        'Sorghum', 'Soya beans', 'Sugar cane', 'Sunflower seed',
#        'Sweet potatoes', 'Tangerines, mandarins, clementines',
#        'Tea leaves', 'Tomatoes', 'True hemp, raw or retted',
#        'Unmanufactured tobacco', 'Walnuts, in shell', 'Watermelons',
#        'Wheat'], dtype=object)

# %%
len(fao['Item'].unique())
# Out:
# 85

# %%
fao.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5940 entries, 0 to 5939
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       5940 non-null   object
#  1   Domain            5940 non-null   object
#  2   Area Code (M49)   5940 non-null   int64
#  3   Area              5940 non-null   object
#  4   Element Code      5940 non-null   int64
#  5   Element           5940 non-null   object
#  6   Item Code (CPC)   5940 non-null   float64
#  7   Item              5940 non-null   object
#  8   Year Code         5940 non-null   int64
#  9   Year              5940 non-null   int64
#  10  Unit              5940 non-null   object
#  11  Value             5727 non-null   float64
#  12  Flag              5940 non-null   object
#  13  Flag Description  5940 non-null   object
#  14  Note              115 non-null    object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 696.2+ KB

# %%
fao.isnull().sum()
# Out:
# Domain Code            0
# Domain                 0
# Area Code (M49)        0
# Area                   0
# Element Code           0
# Element                0
# Item Code (CPC)        0
# Item                   0
# Year Code              0
# Year                   0
# Unit                   0
# Value                213
# Flag                   0
# Flag Description       0
# Note                5825
# dtype: int64

# %% [markdown]
# ## FAO Explode Operation

# %%
fao['Item'] = fao['Item'].str.split(',')
fao = fao.explode('Item')

# %%
fao['Item'] = fao['Item'].str.strip().str.lower()
fao['Item'] = fao['Item'].apply(lambda x: x[:-1] if x.endswith('s') else x)

# %%
print("Explode Shape:", fao.shape)
# Out:
# Explode Shape: (9160, 15)

# %%
fao['Element'].unique()
# Out:
# array(['Area harvested', 'Yield', 'Production'], dtype=object)

# %%
len(fao['Element'].unique())
# Out:
# 3

# %%
fao['Item'].unique()
# Out:
# array(['anise', 'badian', 'coriander', 'cumin', 'caraway',
#        'fennel and juniper berrie', 'raw', 'apple', 'apricot',
#        'areca nut', 'banana', 'barley', 'bean', 'dry', 'cabbage',
#        'cantaloupes and other melon', 'carrots and turnip', 'cashew nut',
#        'in shell', 'cassava', 'fresh', 'castor oil seed',
#        'cauliflowers and broccoli', 'cherrie', 'chick pea',
#        'chillies and pepper', 'dry (capsicum spp.', 'pimenta spp.)',
#        'green (capsicum spp. and pimenta spp.)', 'cocoa bean', 'coconut',
#        'coffee', 'green', 'coir', 'cucumbers and gherkin',
#        'eggplants (aubergines)', 'fig', 'ginger', 'grape', 'green garlic',
#        'groundnut', 'excluding shelled', 'jute', 'raw or retted', 'kenaf',
#        'and other textile bast fibre', 'lemons and lime', 'lentil',
#        'lettuce and chicory', 'linseed', 'maize (corn)', 'mangoe',
#        'guavas and mangosteen', 'millet', 'mushrooms and truffle',
#        'natural rubber in primary form', 'nutmeg', 'mace', 'cardamom',
#        'okra', 'onions and shallot', 'dry (excluding dehydrated)',
#        'orange', 'other bean',
#        'other berries and fruits of the genus vaccinium n.e.c.',
#        'other citrus fruit', 'n.e.c.', 'other fruit', 'other oil seed',
#        'other pulses n.e.c.', 'other stimulant',
#        'spice and aromatic crop', 'other stone fruit',
#        'other tropical fruit', 'other vegetable', 'fresh n.e.c.',
#        'papaya', 'peaches and nectarine', 'pear', 'pea',
#        'pepper (piper spp.)', 'pigeon pea', 'pineapple', 'plums and sloe',
#        'pomelos and grapefruit', 'poppy seed', 'potatoe', 'pumpkin',
#        'squash and gourd', 'rape or colza seed', 'rice', 'safflower seed',
#        'seed cotton', 'unginned', 'sesame seed', 'sorghum', 'soya bean',
#        'sugar cane', 'sunflower seed', 'sweet potatoe', 'tangerine',
#        'mandarin', 'clementine', 'tea leave', 'tomatoe', 'true hemp',
#        'unmanufactured tobacco', 'walnut', 'watermelon', 'wheat'],
#       dtype=object)

# %%
len(fao['Item'].unique())
# Out:
# 110

# %%
fao_production = fao[fao['Element'] == 'Production']

print("FAO Production Data:")
fao_production.head()
# Out:
# FAO Production Data:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 2         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
#
#    Element Code     Element  Item Code (CPC)       Item  Year Code  Year Unit  \
# 2          5510  Production           1654.0      anise       2000  2000    t
# 2          5510  Production           1654.0     badian       2000  2000    t
# 2          5510  Production           1654.0  coriander       2000  2000    t
# 2          5510  Production           1654.0      cumin       2000  2000    t
# 2          5510  Production           1654.0    caraway       2000  2000    t
#
#       Value Flag Flag Description Note
# 2  166692.0    A  Official figure  NaN
# 2  166692.0    A  Official figure  NaN
# 2  166692.0    A  Official figure  NaN
# 2  166692.0    A  Official figure  NaN
# 2  166692.0    A  Official figure  NaN

# %%
print("Shape:", fao_production.shape)
# Out:
# Shape: (3144, 15)

# %%
fao_production.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3144 entries, 2 to 5939
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       3144 non-null   object
#  1   Domain            3144 non-null   object
#  2   Area Code (M49)   3144 non-null   int64
#  3   Area              3144 non-null   object
#  4   Element Code      3144 non-null   int64
#  5   Element           3144 non-null   object
#  6   Item Code (CPC)   3144 non-null   float64
#  7   Item              3144 non-null   object
#  8   Year Code         3144 non-null   int64
#  9   Year              3144 non-null   int64
#  10  Unit              3144 non-null   object
#  11  Value             2986 non-null   float64
#  12  Flag              3144 non-null   object
#  13  Flag Description  3144 non-null   object
#  14  Note              143 non-null    object
# dtypes: float64(2), int64(4), object(9)
# memory usage: 393.0+ KB

# %%
fao_production['Item'].unique()
# Out:
# array(['anise', 'badian', 'coriander', 'cumin', 'caraway',
#        'fennel and juniper berrie', 'raw', 'apple', 'apricot',
#        'areca nut', 'banana', 'barley', 'bean', 'dry', 'cabbage',
#        'cantaloupes and other melon', 'carrots and turnip', 'cashew nut',
#        'in shell', 'cassava', 'fresh', 'castor oil seed',
#        'cauliflowers and broccoli', 'cherrie', 'chick pea',
#        'chillies and pepper', 'dry (capsicum spp.', 'pimenta spp.)',
#        'green (capsicum spp. and pimenta spp.)', 'cocoa bean', 'coconut',
#        'coffee', 'green', 'coir', 'cucumbers and gherkin',
#        'eggplants (aubergines)', 'fig', 'ginger', 'grape', 'green garlic',
#        'groundnut', 'excluding shelled', 'jute', 'raw or retted', 'kenaf',
#        'and other textile bast fibre', 'lemons and lime', 'lentil',
#        'lettuce and chicory', 'linseed', 'maize (corn)', 'mangoe',
#        'guavas and mangosteen', 'millet', 'mushrooms and truffle',
#        'natural rubber in primary form', 'nutmeg', 'mace', 'cardamom',
#        'okra', 'onions and shallot', 'dry (excluding dehydrated)',
#        'orange', 'other bean',
#        'other berries and fruits of the genus vaccinium n.e.c.',
#        'other citrus fruit', 'n.e.c.', 'other fruit', 'other oil seed',
#        'other pulses n.e.c.', 'other stimulant',
#        'spice and aromatic crop', 'other stone fruit',
#        'other tropical fruit', 'other vegetable', 'fresh n.e.c.',
#        'papaya', 'peaches and nectarine', 'pear', 'pea',
#        'pepper (piper spp.)', 'pigeon pea', 'pineapple', 'plums and sloe',
#        'pomelos and grapefruit', 'poppy seed', 'potatoe', 'pumpkin',
#        'squash and gourd', 'rape or colza seed', 'rice', 'safflower seed',
#        'seed cotton', 'unginned', 'sesame seed', 'sorghum', 'soya bean',
#        'sugar cane', 'sunflower seed', 'sweet potatoe', 'tangerine',
#        'mandarin', 'clementine', 'tea leave', 'tomatoe', 'true hemp',
#        'unmanufactured tobacco', 'walnut', 'watermelon', 'wheat'],
#       dtype=object)

# %%
len(fao_production['Item'].unique())
# Out:
# 110

# %% [markdown]
# ## Crop Dataset Details

# %%
crop
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
crop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
crop.isnull().sum()
# Out:
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
crop.shape
# Out:
# (2200, 8)

# %%
crop['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
crop['label'] = crop['label'].str.lower().str.strip()

# %% [markdown]
# ## Merge Both Datasets

# %%
fao_production
# Out:
#      Domain Code                        Domain  Area Code (M49)   Area  \
# 2            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# ...          ...                           ...              ...    ...
# 5927         QCL  Crops and livestock products              356  India
# 5930         QCL  Crops and livestock products              356  India
# 5933         QCL  Crops and livestock products              356  India
# 5936         QCL  Crops and livestock products              356  India
# 5939         QCL  Crops and livestock products              356  India
#
#       Element Code     Element  Item Code (CPC)       Item  Year Code  Year  \
# 2             5510  Production           1654.0      anise       2000  2000
# 2             5510  Production           1654.0     badian       2000  2000
# 2             5510  Production           1654.0  coriander       2000  2000
# 2             5510  Production           1654.0      cumin       2000  2000
# 2             5510  Production           1654.0    caraway       2000  2000
# ...            ...         ...              ...        ...        ...   ...
# 5927          5510  Production            111.0      wheat       2019  2019
# 5930          5510  Production            111.0      wheat       2020  2020
# 5933          5510  Production            111.0      wheat       2021  2021
# 5936          5510  Production            111.0      wheat       2022  2022
# 5939          5510  Production            111.0      wheat       2023  2023
#
#      Unit         Value Flag Flag Description Note
# 2       t  1.666920e+05    A  Official figure  NaN
# 2       t  1.666920e+05    A  Official figure  NaN
# 2       t  1.666920e+05    A  Official figure  NaN
# 2       t  1.666920e+05    A  Official figure  NaN
# 2       t  1.666920e+05    A  Official figure  NaN
# ...   ...           ...  ...              ...  ...
# 5927    t  1.035962e+08    A  Official figure  NaN
# 5930    t  1.078605e+08    A  Official figure  NaN
# 5933    t  1.095865e+08    A  Official figure  NaN
# 5936    t  1.077421e+08    A  Official figure  NaN
# 5939    t  1.105537e+08    A  Official figure  NaN
#
# [3144 rows x 15 columns]

# %%
fao_production['Element'].unique()
# Out:
# array(['Production'], dtype=object)

# %%
fao_production['Item'].unique()
# Out:
# array(['anise', 'badian', 'coriander', 'cumin', 'caraway',
#        'fennel and juniper berrie', 'raw', 'apple', 'apricot',
#        'areca nut', 'banana', 'barley', 'bean', 'dry', 'cabbage',
#        'cantaloupes and other melon', 'carrots and turnip', 'cashew nut',
#        'in shell', 'cassava', 'fresh', 'castor oil seed',
#        'cauliflowers and broccoli', 'cherrie', 'chick pea',
#        'chillies and pepper', 'dry (capsicum spp.', 'pimenta spp.)',
#        'green (capsicum spp. and pimenta spp.)', 'cocoa bean', 'coconut',
#        'coffee', 'green', 'coir', 'cucumbers and gherkin',
#        'eggplants (aubergines)', 'fig', 'ginger', 'grape', 'green garlic',
#        'groundnut', 'excluding shelled', 'jute', 'raw or retted', 'kenaf',
#        'and other textile bast fibre', 'lemons and lime', 'lentil',
#        'lettuce and chicory', 'linseed', 'maize (corn)', 'mangoe',
#        'guavas and mangosteen', 'millet', 'mushrooms and truffle',
#        'natural rubber in primary form', 'nutmeg', 'mace', 'cardamom',
#        'okra', 'onions and shallot', 'dry (excluding dehydrated)',
#        'orange', 'other bean',
#        'other berries and fruits of the genus vaccinium n.e.c.',
#        'other citrus fruit', 'n.e.c.', 'other fruit', 'other oil seed',
#        'other pulses n.e.c.', 'other stimulant',
#        'spice and aromatic crop', 'other stone fruit',
#        'other tropical fruit', 'other vegetable', 'fresh n.e.c.',
#        'papaya', 'peaches and nectarine', 'pear', 'pea',
#        'pepper (piper spp.)', 'pigeon pea', 'pineapple', 'plums and sloe',
#        'pomelos and grapefruit', 'poppy seed', 'potatoe', 'pumpkin',
#        'squash and gourd', 'rape or colza seed', 'rice', 'safflower seed',
#        'seed cotton', 'unginned', 'sesame seed', 'sorghum', 'soya bean',
#        'sugar cane', 'sunflower seed', 'sweet potatoe', 'tangerine',
#        'mandarin', 'clementine', 'tea leave', 'tomatoe', 'true hemp',
#        'unmanufactured tobacco', 'walnut', 'watermelon', 'wheat'],
#       dtype=object)

# %%
crop
# Out:
#         N   P   K  temperature   humidity        ph    rainfall   label
# 0      90  42  43    20.879744  82.002744  6.502985  202.935536    rice
# 1      85  58  41    21.770462  80.319644  7.038096  226.655537    rice
# 2      60  55  44    23.004459  82.320763  7.840207  263.964248    rice
# 3      74  35  40    26.491096  80.158363  6.980401  242.864034    rice
# 4      78  42  42    20.130175  81.604873  7.628473  262.717340    rice
# ...   ...  ..  ..          ...        ...       ...         ...     ...
# 2195  107  34  32    26.774637  66.413269  6.780064  177.774507  coffee
# 2196   99  15  27    27.417112  56.636362  6.086922  127.924610  coffee
# 2197  118  33  30    24.131797  67.225123  6.362608  173.322839  coffee
# 2198  117  32  34    26.272418  52.127394  6.758793  127.175293  coffee
# 2199  104  18  30    23.603016  60.396475  6.779833  140.937041  coffee
#
# [2200 rows x 8 columns]

# %%
crop['label'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'kidneybeans', 'pigeonpeas',
#        'mothbeans', 'mungbean', 'blackgram', 'lentil', 'pomegranate',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
reverse_mapping = {
    'apples':'apple',
    'bananas':'banana',
    'chick pea':'chickpea',
    'coconut':'coconut',
    'coffee':'coffee',
    'seed cotton':'cotton',
    'grape':'grapes',
    'jute':'jute',
    'lentil':'lentil',
    'maize (corn)':'maize',
    'mangoe':'mango',
    'bean':'mothbeans',  # incorrect category → drop later
    'cantaloupes and other melon':'muskmelon',
    'orange':'orange',
    'papaya':'papaya',
    'pigeon pea':'pigeonpeas',
    'rice':'rice',
    'watermelon':'watermelon'
}

# %%
fao_production['crop_clean'] = fao_production['Item'].map(reverse_mapping)
fao_production = fao_production.dropna(subset=['crop_clean'])
# Out:
# /tmp/ipython-input-2627479932.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   fao_production['crop_clean'] = fao_production['Item'].map(reverse_mapping)

# %%
merged = pd.merge(
    fao_production,
    crop,
    left_on='crop_clean',
    right_on='label',
    how='inner'
)
print("Merged Shape:", merged.shape)
# Out:
# Merged Shape: (38400, 24)

# %%
merged
# Out:
#       Domain Code                        Domain  Area Code (M49)   Area  \
# 0             QCL  Crops and livestock products              356  India
# 1             QCL  Crops and livestock products              356  India
# 2             QCL  Crops and livestock products              356  India
# 3             QCL  Crops and livestock products              356  India
# 4             QCL  Crops and livestock products              356  India
# ...           ...                           ...              ...    ...
# 38395         QCL  Crops and livestock products              356  India
# 38396         QCL  Crops and livestock products              356  India
# 38397         QCL  Crops and livestock products              356  India
# 38398         QCL  Crops and livestock products              356  India
# 38399         QCL  Crops and livestock products              356  India
#
#        Element Code     Element  Item Code (CPC)        Item  Year Code  Year  \
# 0              5510  Production           1701.0        bean       2000  2000
# 1              5510  Production           1701.0        bean       2000  2000
# 2              5510  Production           1701.0        bean       2000  2000
# 3              5510  Production           1701.0        bean       2000  2000
# 4              5510  Production           1701.0        bean       2000  2000
# ...             ...         ...              ...         ...        ...   ...
# 38395          5510  Production           1221.0  watermelon       2023  2023
# 38396          5510  Production           1221.0  watermelon       2023  2023
# 38397          5510  Production           1221.0  watermelon       2023  2023
# 38398          5510  Production           1221.0  watermelon       2023  2023
# 38399          5510  Production           1221.0  watermelon       2023  2023
#
#        ... Note  crop_clean    N   P   K temperature   humidity        ph  \
# 0      ...  NaN   mothbeans    3  49  18   27.910952  64.709306  3.692864
# 1      ...  NaN   mothbeans   22  59  23   27.322206  51.278688  4.371746
# 2      ...  NaN   mothbeans   36  58  25   28.660242  59.318912  8.399136
# 3      ...  NaN   mothbeans    4  43  18   29.029553  61.093875  8.840656
# 4      ...  NaN   mothbeans   29  54  16   27.780315  54.650300  8.153023
# ...    ...  ...         ...  ...  ..  ..         ...        ...       ...
# 38395  ...  NaN  watermelon   97  12  47   25.287846  89.636679  6.765095
# 38396  ...  NaN  watermelon  110   7  45   26.638386  84.695469  6.189214
# 38397  ...  NaN  watermelon   96  18  50   25.331045  84.305338  6.904242
# 38398  ...  NaN  watermelon   83  23  55   26.897502  83.892415  6.463271
# 38399  ...  NaN  watermelon  120  24  47   26.986037  89.413849  6.260839
#
#         rainfall       label
# 0      32.678919   mothbeans
# 1      36.503791   mothbeans
# 2      36.926297   mothbeans
# 3      72.980166   mothbeans
# 4      32.050253   mothbeans
# ...          ...         ...
# 38395  58.286977  watermelon
# 38396  48.324286  watermelon
# 38397  41.532187  watermelon
# 38398  43.971937  watermelon
# 38399  58.548767  watermelon
#
# [38400 rows x 24 columns]

# %%
merged['crop_clean'].unique()
# Out:
# array(['mothbeans', 'muskmelon', 'chickpea', 'coconut', 'coffee',
#        'grapes', 'jute', 'lentil', 'maize', 'mango', 'orange', 'papaya',
#        'pigeonpeas', 'rice', 'cotton', 'watermelon'], dtype=object)

# %%
merged['label'].unique()
# Out:
# array(['mothbeans', 'muskmelon', 'chickpea', 'coconut', 'coffee',
#        'grapes', 'jute', 'lentil', 'maize', 'mango', 'orange', 'papaya',
#        'pigeonpeas', 'rice', 'cotton', 'watermelon'], dtype=object)

# %%
merged['Element'].unique()
# Out:
# array(['Production'], dtype=object)

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38400 entries, 0 to 38399
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       38400 non-null  object
#  1   Domain            38400 non-null  object
#  2   Area Code (M49)   38400 non-null  int64
#  3   Area              38400 non-null  object
#  4   Element Code      38400 non-null  int64
#  5   Element           38400 non-null  object
#  6   Item Code (CPC)   38400 non-null  float64
#  7   Item              38400 non-null  object
#  8   Year Code         38400 non-null  int64
#  9   Year              38400 non-null  int64
#  10  Unit              38400 non-null  object
#  11  Value             38400 non-null  float64
#  12  Flag              38400 non-null  object
#  13  Flag Description  38400 non-null  object
#  14  Note              300 non-null    object
#  15  crop_clean        38400 non-null  object
#  16  N                 38400 non-null  int64
#  17  P                 38400 non-null  int64
#  18  K                 38400 non-null  int64
#  19  temperature       38400 non-null  float64
#  20  humidity          38400 non-null  float64
#  21  ph                38400 non-null  float64
#  22  rainfall          38400 non-null  float64
#  23  label             38400 non-null  object
# dtypes: float64(6), int64(7), object(11)
# memory usage: 7.0+ MB

# %%
merged.isnull().sum()
# Out:
# Domain Code             0
# Domain                  0
# Area Code (M49)         0
# Area                    0
# Element Code            0
# Element                 0
# Item Code (CPC)         0
# Item                    0
# Year Code               0
# Year                    0
# Unit                    0
# Value                   0
# Flag                    0
# Flag Description        0
# Note                38100
# crop_clean              0
# N                       0
# P                       0
# K                       0
# temperature             0
# humidity                0
# ph                      0
# rainfall                0
# label                   0
# dtype: int64

# %% [markdown]
# ## Drop irrelevant Column Data

# %%
columns_to_drop = [
    'Domain Code', 'Domain', 'Area Code (M49)', 'Area',
    'Element Code','Item Code (CPC)','item',
    'Year Code', 'Year', 'Unit', 'Flag',
    'Flag Description', 'Note'
]

# %%
merged.drop(columns=[c for c in columns_to_drop if c in merged.columns],inplace=True)

# %%
merged
# Out:
#           Element        Item      Value  crop_clean    N   P   K  \
# 0      Production        bean  2847000.0   mothbeans    3  49  18
# 1      Production        bean  2847000.0   mothbeans   22  59  23
# 2      Production        bean  2847000.0   mothbeans   36  58  25
# 3      Production        bean  2847000.0   mothbeans    4  43  18
# 4      Production        bean  2847000.0   mothbeans   29  54  16
# ...           ...         ...        ...         ...  ...  ..  ..
# 38395  Production  watermelon  3626000.0  watermelon   97  12  47
# 38396  Production  watermelon  3626000.0  watermelon  110   7  45
# 38397  Production  watermelon  3626000.0  watermelon   96  18  50
# 38398  Production  watermelon  3626000.0  watermelon   83  23  55
# 38399  Production  watermelon  3626000.0  watermelon  120  24  47
#
#        temperature   humidity        ph   rainfall       label
# 0        27.910952  64.709306  3.692864  32.678919   mothbeans
# 1        27.322206  51.278688  4.371746  36.503791   mothbeans
# 2        28.660242  59.318912  8.399136  36.926297   mothbeans
# 3        29.029553  61.093875  8.840656  72.980166   mothbeans
# 4        27.780315  54.650300  8.153023  32.050253   mothbeans
# ...            ...        ...       ...        ...         ...
# 38395    25.287846  89.636679  6.765095  58.286977  watermelon
# 38396    26.638386  84.695469  6.189214  48.324286  watermelon
# 38397    25.331045  84.305338  6.904242  41.532187  watermelon
# 38398    26.897502  83.892415  6.463271  43.971937  watermelon
# 38399    26.986037  89.413849  6.260839  58.548767  watermelon
#
# [38400 rows x 12 columns]

# %%
final_data = merged[['Element', 'Value', 'N', 'P', 'K',
                      'temperature', 'humidity', 'ph', 'rainfall', 'label']]

print("Final dataset ready!")
# Out:
# Final dataset ready!

# %%
final_data.head()
# Out:
#       Element      Value   N   P   K  temperature   humidity        ph  \
# 0  Production  2847000.0   3  49  18    27.910952  64.709306  3.692864
# 1  Production  2847000.0  22  59  23    27.322206  51.278688  4.371746
# 2  Production  2847000.0  36  58  25    28.660242  59.318912  8.399136
# 3  Production  2847000.0   4  43  18    29.029553  61.093875  8.840656
# 4  Production  2847000.0  29  54  16    27.780315  54.650300  8.153023
#
#     rainfall      label
# 0  32.678919  mothbeans
# 1  36.503791  mothbeans
# 2  36.926297  mothbeans
# 3  72.980166  mothbeans
# 4  32.050253  mothbeans

# %%
final_data.shape
# Out:
# (38400, 10)

# %%
final_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38400 entries, 0 to 38399
# Data columns (total 10 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Element      38400 non-null  object
#  1   Value        38400 non-null  float64
#  2   N            38400 non-null  int64
#  3   P            38400 non-null  int64
#  4   K            38400 non-null  int64
#  5   temperature  38400 non-null  float64
#  6   humidity     38400 non-null  float64
#  7   ph           38400 non-null  float64
#  8   rainfall     38400 non-null  float64
#  9   label        38400 non-null  object
# dtypes: float64(5), int64(3), object(2)
# memory usage: 2.9+ MB

# %% [markdown]
# ## EDA (Exploratory Data Analysis) Perform On Final_Data

# %%
print(final_data.describe())
# Out:
#               Value             N             P             K   temperature  \
# count  3.840000e+04  38400.000000  38400.000000  38400.000000  38400.000000
# mean   1.571140e+07     55.655000     47.294375     44.373125     25.818599
# std    3.744192e+07     37.499001     29.577555     43.734997      5.345334
# min    2.550000e+05      0.000000      5.000000      5.000000      8.825675
# 25%    1.642652e+06     24.000000     25.000000     21.000000     23.191957
# 50%    3.494000e+06     44.000000     45.000000     32.000000     25.695781
# 75%    1.140689e+07     89.000000     60.000000     48.000000     28.663703
# max    2.067270e+08    140.000000    145.000000    205.000000     43.675493
#
#            humidity            ph      rainfall
# count  38400.000000  38400.000000  38400.000000
# mean      71.097399      6.523657    108.073918
# std       21.321480      0.827210     61.637343
# min       14.258040      3.504752     20.211267
# 25%       57.358887      6.078786     63.714673
# 50%       79.631415      6.474876     91.798971
# 75%       89.989593      6.960865    154.701627
# max       99.981876      9.935091    298.560117

# %%
print("\nMissing Values Before Handling:")
print(final_data.isnull().sum())
# Out:
# Missing Values Before Handling:
# Element        0
# Value          0
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
final_data = final_data.dropna()
print("\nMissing Values After Handling:")
print(final_data.isnull().sum())
# Out:
# Missing Values After Handling:
# Element        0
# Value          0
# N              0
# P              0
# K              0
# temperature    0
# humidity       0
# ph             0
# rainfall       0
# label          0
# dtype: int64

# %%
print("\nDuplicate rows before drop:", final_data.duplicated().sum())
final_data = final_data.drop_duplicates()
print("Duplicate rows after drop:", final_data.duplicated().sum())
# Out:
# Duplicate rows before drop: 600
# Duplicate rows after drop: 0

# %%
final_data['Element'].unique()
# Out:
# array(['Production'], dtype=object)

# %%
final_data['label'].unique()
# Out:
# array(['mothbeans', 'muskmelon', 'chickpea', 'coconut', 'coffee',
#        'grapes', 'jute', 'lentil', 'maize', 'mango', 'orange', 'papaya',
#        'pigeonpeas', 'rice', 'cotton', 'watermelon'], dtype=object)

# %% [markdown]
# ## BOXPLOTS FOR OUTLIERS (Final_Data)

# %% [markdown]
# ### 1. Boxplots BEFORE Outlier Removal

# %%
import matplotlib.pyplot as plt
import seaborn as sns

numeric_cols = ['Value', 'N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall']

plt.figure(figsize=(15, 6))
sns.boxplot(data=final_data[numeric_cols], orient='h')
plt.title("Boxplots BEFORE Outlier Removal", fontsize=16)
plt.xlabel("Value Range")
plt.show()

# %% [markdown]
# ### 2. Remove Outliers Using IQR Method

# %%
def remove_outliers_iqr(df, cols):
    df_clean = df.copy()
    for col in cols:
        Q1 = df_clean[col].quantile(0.25)
        Q3 = df_clean[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        df_clean = df_clean[(df_clean[col] >= lower) & (df_clean[col] <= upper)]
    return df_clean

cleaned_data = remove_outliers_iqr(final_data, numeric_cols)
print("Shape Before:", final_data.shape)
print("Shape After Outlier Removal:", cleaned_data.shape)
# Out:
# Shape Before: (37800, 10)
# Shape After Outlier Removal: (28847, 10)

# %% [markdown]
# ### 3. Boxplots AFTER Outlier Removal

# %%
plt.figure(figsize=(15, 6))
sns.boxplot(data=cleaned_data[numeric_cols], orient='h')
plt.title("Boxplots AFTER Outlier Removal", fontsize=16)
plt.xlabel("Value Range")
plt.show()

# %% [markdown]
# ### 4. Correlation Heatmap

# %%
plt.figure(figsize=(10,6))
sns.heatmap(cleaned_data[numeric_cols].corr(), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap on Cleaned Data", fontsize=16)
plt.show()

# %% [markdown]
# ### 5. Pairplot (Limit to 400 rows for speed)

# %%
sample_data = cleaned_data.sample(n=400, random_state=42)

sns.pairplot(sample_data[numeric_cols + ['label']], hue='label')
plt.show()

# %% [markdown]
# ### 6. Export Final Cleaned CSV

# %%
cleaned_data.to_csv("final_cleaned_dataset.csv", index=False)
print("Cleaned CSV Saved Successfully!")
# Out:
# Cleaned CSV Saved Successfully!

# %%
cleaned_data.head()
# Out:
#       Element      Value   N   P   K  temperature   humidity        ph  \
# 4  Production  2847000.0  29  54  16    27.780315  54.650300  8.153023
# 5  Production  2847000.0  32  43  22    31.999286  54.107746  5.270749
# 6  Production  2847000.0  14  55  15    27.335809  55.277559  8.050304
# 8  Production  2847000.0  25  57  24    27.654722  58.599863  6.974978
# 9  Production  2847000.0  11  53  24    28.523967  55.772644  7.393899
#
#     rainfall      label
# 4  32.050253  mothbeans
# 5  71.626670  mothbeans
# 6  73.447753  mothbeans
# 8  36.942550  mothbeans
# 9  61.329356  mothbeans

# %%
cleaned_data['label'].unique()
# Out:
# array(['mothbeans', 'muskmelon', 'chickpea', 'coconut', 'coffee', 'jute',
#        'lentil', 'maize', 'mango', 'orange', 'papaya', 'pigeonpeas',
#        'cotton', 'watermelon'], dtype=object)

# %%
cleaned_data.shape
# Out:
# (28847, 10)

# %% [markdown]
# # Milestone 2: Week 3 & 4 - EDA & Feature Engineering

# %% [markdown]
# • Visualize relationships between features and yield.
#
# • Identify important variables (e.g., NPK levels, rainfall).
#
# • Encode categorical features (e.g., soil type, crop name).
#
# • Engineer new features like growing season index, heat days, etc.
