# %%
import pandas as pd
import numpy as np

# %%
df4=pd.read_csv('final.csv')
# Out:
# C:\Users\skart\AppData\Local\Temp\ipykernel_17284\701585182.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('final.csv')

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...  Year Code  Year   Unit        Value  \
# 0  Crops and livestock products  ...       2004  2004     ha   41906700.0
# 1  Crops and livestock products  ...       2004  2004  kg/ha       2975.6
# 2  Crops and livestock products  ...       2004  2004      t  124697104.0
# 3  Crops and livestock products  ...       2005  2005     ha   43659800.0
# 4  Crops and livestock products  ...       2005  2005  kg/ha       3153.7
#
# ...

# %%
df4=df4.drop(columns=['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
       'Element', 'Item Code (CPC)', 'Item', 'Year Code','Unit',
       'Value', 'Flag', 'Flag Description', 'Note'])

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
#
#    Area_Harvested   Production   Yield
# 0      41906700.0  124697104.0  2975.6
# 1      41906700.0  124697104.0  2975.6
# 2      41906700.0  124697104.0  2975.6
# 3      43659800.0  137690096.0  3153.7
# 4      43659800.0  137690096.0  3153.7

# %%
df4.isnull().any()
# Out:
# N                 False
# P                 False
# K                 False
# temperature       False
# humidity          False
# ph                False
# rainfall          False
# Crop              False
# Year              False
# Area_Harvested    False
# Production        False
# Yield             False
# dtype: bool

# %%
df4=df4.drop_duplicates().reset_index(drop=True)

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2006
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2007
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2008
#
#    Area_Harvested   Production   Yield
# 0      41906700.0  124697104.0  2975.6
# 1      43659800.0  137690096.0  3153.7
# 2      43810000.0  139136992.0  3175.9
# 3      43910000.0  144570000.0  3292.4
# 4      45537400.0  148036000.0  3250.9

# %%
len(df4)
# Out:
# 28000

# %%
df4.dtypes
# Out:
# N                   int64
# P                   int64
# K                   int64
# temperature       float64
# humidity          float64
# ph                float64
# rainfall          float64
# Crop               object
# Year                int64
# Area_Harvested    float64
# Production        float64
# Yield             float64
# dtype: object

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encoder=LabelEncoder()

# %%
df4['Crops']=encoder.fit_transform(df4['Crop'])

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2006
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2007
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2008
#
#    Area_Harvested   Production   Yield  Crops
# 0      41906700.0  124697104.0  2975.6     12
# 1      43659800.0  137690096.0  3153.7     12
# 2      43810000.0  139136992.0  3175.9     12
# 3      43910000.0  144570000.0  3292.4     12
# 4      45537400.0  148036000.0  3250.9     12
