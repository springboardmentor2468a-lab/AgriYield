# %%
import pandas as pd
import numpy as np

# %%
df1=pd.read_csv("Crop_recommendation.csv")

# %%
df1.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df1.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label'], dtype='object')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2200 entries, 0 to 2199
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   N            2200 non-null   int64
#  1   P            2200 non-null   int64
#  2   K            2200 non-null   int64
#  3   temperature  2200 non-null   float64
#  4   humidity     2200 non-null   float64
#  5   ph           2200 non-null   float64
#  6   rainfall     2200 non-null   float64
#  7   label        2200 non-null   object
# dtypes: float64(4), int64(3), object(1)
# memory usage: 137.6+ KB

# %%
df1.isnull().any()
# Out:
# N              False
# P              False
# K              False
# temperature    False
# humidity       False
# ph             False
# rainfall       False
# label          False
# dtype: bool

# %%
df1['label'].value_counts()
# Out:
# label
# rice           100
# maize          100
# chickpea       100
# kidneybeans    100
# pigeonpeas     100
# mothbeans      100
# mungbean       100
# blackgram      100
# lentil         100
# pomegranate    100
# banana         100
# mango          100
# grapes         100
# watermelon     100
# muskmelon      100
# apple          100
# orange         100
# papaya         100
# coconut        100
# cotton         100
# jute           100
# coffee         100
# Name: count, dtype: int64

# %%
df1=df1.rename(columns={'label':'Crop'})

# %%
df1.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df2=pd.read_csv("FAOSTAT_data_en_11-19-2025.csv")

# %%
df2.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)  \
# 0          5312  Area harvested           01654
# 1          5412           Yield           01654
# 2          5510      Production           01654
# 3          5312  Area harvested           01654
# 4          5412           Yield           01654
#
#                                                 Item  Year Code  Year   Unit  \
# 0  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004     ha
# 1  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004  kg/ha
# 2  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004      t
# 3  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005     ha
# 4  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005  kg/ha
#
#       Value Flag Flag Description Note
# 0  410573.0    A  Official figure  NaN
# 1     553.1    A  Official figure  NaN
# 2  227099.0    A  Official figure  NaN
# 3  446931.0    A  Official figure  NaN
# 4     584.4    A  Official figure  NaN

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5261 entries, 0 to 5260
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Domain Code       5261 non-null   object
#  1   Domain            5261 non-null   object
#  2   Area Code (M49)   5261 non-null   int64
#  3   Area              5261 non-null   object
#  4   Element Code      5261 non-null   int64
#  5   Element           5261 non-null   object
#  6   Item Code (CPC)   5261 non-null   object
#  7   Item              5261 non-null   object
#  8   Year Code         5261 non-null   int64
#  9   Year              5261 non-null   int64
#  10  Unit              5261 non-null   object
#  11  Value             5076 non-null   float64
#  12  Flag              5261 non-null   object
#  13  Flag Description  5261 non-null   object
#  14  Note              227 non-null    object
# dtypes: float64(1), int64(4), object(10)
# memory usage: 616.7+ KB

# %%
df2.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
df2.isnull().any()
# Out:
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value                True
# Flag                False
# Flag Description    False
# Note                 True
# dtype: bool

# %%
len(df2)
# Out:
# 5261

# %%
df2[df2.isnull().any(axis=1)]
# Out:
#      Domain Code                        Domain  Area Code (M49)   Area  \
# 0            QCL  Crops and livestock products              356  India
# 1            QCL  Crops and livestock products              356  India
# 2            QCL  Crops and livestock products              356  India
# 3            QCL  Crops and livestock products              356  India
# 4            QCL  Crops and livestock products              356  India
# ...          ...                           ...              ...    ...
# 5256         QCL  Crops and livestock products              356  India
# 5257         QCL  Crops and livestock products              356  India
# 5258         QCL  Crops and livestock products              356  India
# 5259         QCL  Crops and livestock products              356  India
# 5260         QCL  Crops and livestock products              356  India
#
#       Element Code         Element Item Code (CPC)  \
# 0             5312  Area harvested           01654
# 1             5412           Yield           01654
# 2             5510      Production           01654
# 3             5312  Area harvested           01654
# 4             5412           Yield           01654
# ...            ...             ...             ...
# 5256          5412           Yield            0111
# 5257          5510      Production            0111
# 5258          5312  Area harvested            0111
# 5259          5412           Yield            0111
# 5260          5510      Production            0111
#
#                                                    Item  Year Code  Year  \
# 0     Anise, badian, coriander, cumin, caraway, fenn...       2004  2004
# 1     Anise, badian, coriander, cumin, caraway, fenn...       2004  2004
# 2     Anise, badian, coriander, cumin, caraway, fenn...       2004  2004
# 3     Anise, badian, coriander, cumin, caraway, fenn...       2005  2005
# 4     Anise, badian, coriander, cumin, caraway, fenn...       2005  2005
# ...                                                 ...        ...   ...
# 5256                                              Wheat       2022  2022
# 5257                                              Wheat       2022  2022
# 5258                                              Wheat       2023  2023
# 5259                                              Wheat       2023  2023
# 5260                                              Wheat       2023  2023
#
#        Unit         Value Flag Flag Description Note
# 0        ha  4.105730e+05    A  Official figure  NaN
# 1     kg/ha  5.531000e+02    A  Official figure  NaN
# 2         t  2.270990e+05    A  Official figure  NaN
# 3        ha  4.469310e+05    A  Official figure  NaN
# 4     kg/ha  5.844000e+02    A  Official figure  NaN
# ...     ...           ...  ...              ...  ...
# 5256  kg/ha  3.537300e+03    A  Official figure  NaN
# 5257      t  1.077421e+08    A  Official figure  NaN
# 5258     ha  3.140072e+07    A  Official figure  NaN
# 5259  kg/ha  3.520700e+03    A  Official figure  NaN
# 5260      t  1.105537e+08    A  Official figure  NaN
#
# [5034 rows x 15 columns]

# %%
len(df2[df2.isnull().any(axis=1)])
# Out:
# 5034

# %%
df2.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)  \
# 0          5312  Area harvested           01654
# 1          5412           Yield           01654
# 2          5510      Production           01654
# 3          5312  Area harvested           01654
# 4          5412           Yield           01654
#
#                                                 Item  Year Code  Year   Unit  \
# 0  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004     ha
# 1  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004  kg/ha
# 2  Anise, badian, coriander, cumin, caraway, fenn...       2004  2004      t
# 3  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005     ha
# 4  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005  kg/ha
#
#       Value Flag Flag Description Note
# 0  410573.0    A  Official figure  NaN
# 1     553.1    A  Official figure  NaN
# 2  227099.0    A  Official figure  NaN
# 3  446931.0    A  Official figure  NaN
# 4     584.4    A  Official figure  NaN

# %%
df2['Item'] = df2['Item'].str.split(r",|and")
df2 = df2.explode('Item')

# %%
df2['Item']=df2['Item'].str.strip()

# %%
df2.columns
# Out:
# Index(['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
for i in df2['Item'].unique():
    print(i)
# Out:
# Anise
# badian
# cori
# er
# cumin
# caraway
# fennel
# juniper berries
# raw
# Apples
# Apricots
# Areca nuts
# Bananas
# Barley
# Beans
# dry
# Beer of barley
# malted
# Cabbages
# Cantaloupes
# other melons
# Carrots
# turnips
# Cashew nuts
# in shell
# Cassava
# fresh
# Castor oil seeds
# Cauliflowers
# broccoli
# Cherries
# Chick peas
# Chillies
# peppers
# dry (Capsicum spp.
# Pimenta spp.)
# green (Capsicum spp.
# Cocoa beans
# Coconut oil
# Coconuts
# Coffee
# green
# Coir
# Cotton lint
# ginned
# Cotton seed
# Cottonseed oil
# Cucumbers
# gherkins
# Eggplants (aubergines)
# Figs
# Ginger
# Grapes
# Green garlic
# Green tea (not fermented)
# black tea (fermented)
# partly fermented tea
# in immediate packings of a content not exceeding 3 kg
# Groundnut oil
# Groundnuts
# excluding shelled
# Jute
# raw or retted
# Kenaf
#
# other textile bast fibres
# Lemons
# limes
# Lentils
# Lettuce
# chicory
# Linseed
# Maize (corn)
# Mangoes
# guavas
# mangosteens
# Margarine
# shortening
# Millet
# Molasses
# Mushrooms
# truffles
# Natural rubber in primary forms
# Nutmeg
# mace
# cardamoms
# Oil of linseed
# Oil of maize
# Oil of sesame seed
# Okra
# Onions
# shallots
# dry (excluding dehydrated)
# Oranges
# Other beans
# Other berries
# fruits of the genus vaccinium n.e.c.
# Other citrus fruit
# n.e.c.
# Other fruits
# Other oil seeds
# Other pulses n.e.c.
# Other stimulant
# spice
# aromatic crops
# Other stone fruits
# Other tropical fruits
# Other vegetables
# fresh n.e.c.
# Papayas
# Peaches
# nectarines
# Pears
# Peas
# Pepper (Piper spp.)
# Pigeon peas
# Pineapples
# Plums
# sloes
# Pomelos
# grapefruits
# Poppy seed
# Potatoes
# Pumpkins
# squash
# gourds
# Rape or colza seed
# Rapeseed or canola oil
# crude
# Raw cane or beet sugar (centrifugal only)
# Rice
# Safflower seed
# Safflower-seed oil
# Seed cotton
# unginned
# Sesame seed
# Sorghum
# Soya bean oil
# Soya beans
# Sugar cane
# Sunflower seed
# Sunflower-seed oil
# Sweet potatoes
# Tangerines
# m
# arins
# clementines
# Tea leaves
# Tomatoes
# True hemp
# Unmanufactured tobacco
# Walnuts
# Watermelons
# Wheat

# %%
len(df2['Item'].unique())
# Out:
# 154

# %%
clean_crop_names = {
    "Anise": "anise",
    "badian": "badian",
    "cori": "cori",
    "er": "er",
    "cumin": "cumin",
    "caraway": "caraway",
    "fennel": "fennel",
    "juniper berries": "juniper_berries",

    "Apples": "apple",
    "Apricots": "apricot",
    "Areca nuts": "areca_nut",
    "Bananas": "banana",
    "Barley": "barley",

    "Beans": "bean",
    "dry": "dry",

    "Cabbages": "cabbage",
    "Cantaloupes": "muskmelon",
    "other melons": "muskmelon",
    "Carrots": "carrot",
    "turnips": "turnip",

    "Cashew nuts": "cashew",
    "in shell": "in_shell",

    "Cassava": "cassava",
    "fresh": "fresh",

    "Castor oil seeds": "castor_seed",
    "Cauliflowers": "cauliflower",
    "broccoli": "broccoli",

    "Cherries": "cherry",
    "Chick peas": "chickpea",

    "Chillies": "chilli",
    "peppers": "pepper",
    "dry (Capsicum spp.)": "dry_capsicum",
    "Pimenta spp.)": "pimenta_spp",
    "green (Capsicum spp.)": "green_capsicum",

    "Cocoa beans": "cocoa",
    "Coconuts": "coconut",
    "Coffee": "coffee",
    "green": "green",

    "Cucumbers": "cucumber",
    "gherkins": "gherkin",

    "Eggplants (aubergines)": "eggplant",
    "Figs": "fig",
    "Ginger": "ginger",
    "Grapes": "grapes",

    "Green garlic": "green_garlic",
    "Groundnuts": "groundnut",
    "excluding shelled": "excluding_shelled",

    "Jute": "jute",
    "raw or retted": "raw_retted",

    "Kenaf": "kenaf",
    "other textile bast fibres": "bast_fibres",

    "Lemons": "lemon",
    "limes": "lime",

    "Lentils": "lentil",
    "Lettuce": "lettuce",
    "chicory": "chicory",

    "Linseed": "linseed",
    "Maize (corn)": "maize",

    "Mangoes": "mango",
    "guavas": "guava",
    "mangosteens": "mangosteen",

    "Millet": "millet",
    "Natural rubber in primary forms": "natural_rubber",

    "Nutmeg": "nutmeg",
    "mace": "mace",
    "cardamoms": "cardamom",

    "Okra": "okra",
    "Onions": "onion",
    "shallots": "shallot",
    "dry (excluding dehydrated)": "dry_non_dehydrated",

    "Oranges": "orange",

    "Other beans": "mothbeans",
    "Other berries": "other_berries",
    "fruits of the genus vaccinium n.e.c.": "vaccinium_fruits",

    "Other citrus fruit": "other_citrus",
    "n.e.c.": "nec",

    "Other fruits": "other_fruits",
    "Other oil seeds": "other_oilseeds",
    "Other pulses n.e.c.": "other_pulses",
    "Other stimulant": "other_stimulant",
    "spice": "spice",
    "aromatic crops": "aromatic_crops",

    "Other stone fruits": "stone_fruits",
    "Other tropical fruits": "tropical_fruits",
    "Other vegetables": "other_vegetables",
    "fresh n.e.c.": "fresh_nec",

    "Papayas": "papaya",
    "Peaches": "peach",
    "nectarines": "nectarine",

    "Pears": "pear",
    "Peas": "pea",

    "Pepper (Piper spp.)": "pepper_piper",
    "Pigeon peas": "pigeonpeas",
    "Pineapples": "pineapple",

    "Plums": "plum",
    "sloes": "sloe",

    "Pomelos": "pomelo",
    "grapefruits": "grapefruit",

    "Potatoes": "potato",
    "Pumpkins": "pumpkin",
    "squash": "squash",
    "gourds": "gourd",

    "Rape or colza seed": "rapeseed",
    "Rice": "rice",
    "Safflower seed": "safflower",

    "Seed cotton": "cotton",
    "unginned": "unginned",

    "Sesame seed": "sesame",
    "Sorghum": "sorghum",
    "Soya beans": "soybean",
    "Sugar cane": "sugarcane",
    "Sunflower seed": "sunflower",

    "Sweet potatoes": "sweet_potato",

    "Tangerines": "tangerine",
    "marins": "marin",
    "clementines": "clementine",

    "Tea leaves": "tea",
    "Tomatoes": "tomato",
    "Unmanufactured tobacco": "tobacco",
    "Walnuts": "walnut",
    "Watermelons": "watermelon",
    "Wheat": "wheat"
}

# %%
len(clean_crop_names)
# Out:
# 122

# %%
df2['Crop']=df2['Item'].map(clean_crop_names)

# %%
common_crops = set(df2['Crop']).intersection(set(df1['Crop']))
common_crops
# Out:
# {'apple',
#  'banana',
#  'chickpea',
#  'coconut',
#  'coffee',
#  'cotton',
#  'grapes',
#  'jute',
#  'lentil',
#  'maize',
#  'mango',
#  'mothbeans',
#  'muskmelon',
#  'orange',
#  'papaya',
#  'pigeonpeas',
#  'rice',
#  'watermelon'}

# %%
df2.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)    Item  Year Code  Year Unit  \
# 0          5312  Area harvested           01654   Anise       2004  2004   ha
# 0          5312  Area harvested           01654  badian       2004  2004   ha
# 0          5312  Area harvested           01654    cori       2004  2004   ha
# 0          5312  Area harvested           01654      er       2004  2004   ha
# 0          5312  Area harvested           01654   cumin       2004  2004   ha
#
#       Value Flag Flag Description Note    Crop
# 0  410573.0    A  Official figure  NaN   anise
# 0  410573.0    A  Official figure  NaN  badian
# 0  410573.0    A  Official figure  NaN    cori
# 0  410573.0    A  Official figure  NaN      er
# 0  410573.0    A  Official figure  NaN   cumin

# %%
len(df2[df2.isnull().any(axis=1)])
# Out:
# 9216

# %%
df2.head()
# Out:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
# 0         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)    Item  Year Code  Year Unit  \
# 0          5312  Area harvested           01654   Anise       2004  2004   ha
# 0          5312  Area harvested           01654  badian       2004  2004   ha
# 0          5312  Area harvested           01654    cori       2004  2004   ha
# 0          5312  Area harvested           01654      er       2004  2004   ha
# 0          5312  Area harvested           01654   cumin       2004  2004   ha
#
#       Value Flag Flag Description Note    Crop
# 0  410573.0    A  Official figure  NaN   anise
# 0  410573.0    A  Official figure  NaN  badian
# 0  410573.0    A  Official figure  NaN    cori
# 0  410573.0    A  Official figure  NaN      er
# 0  410573.0    A  Official figure  NaN   cumin

# %%
df2.isnull().any()
# Out:
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value                True
# Flag                False
# Flag Description    False
# Note                 True
# Crop                 True
# dtype: bool

# %%
len(df2)
# Out:
# 9338

# %%
len(df2[df2.isnull().any(axis=1)])
# Out:
# 9216

# %%
df2.isnull().any()
# Out:
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value                True
# Flag                False
# Flag Description    False
# Note                 True
# Crop                 True
# dtype: bool

# %%
df3=pd.merge(df1,df2,on='Crop')

# %%
df3['Crop'].unique()
# Out:
# array(['rice', 'maize', 'chickpea', 'pigeonpeas', 'mothbeans', 'lentil',
#        'banana', 'mango', 'grapes', 'watermelon', 'muskmelon', 'apple',
#        'orange', 'papaya', 'coconut', 'cotton', 'jute', 'coffee'],
#       dtype=object)

# %%
df3.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested            0113  Rice
# 1  Crops and livestock products  ...           Yield            0113  Rice
# 2  Crops and livestock products  ...      Production            0113  Rice
# 3  Crops and livestock products  ...  Area harvested            0113  Rice
# 4  Crops and livestock products  ...           Yield            0113  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df3.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'Crop',
#        'Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
df3.isnull().any()
# Out:
# N                   False
# P                   False
# K                   False
# temperature         False
# humidity            False
# ph                  False
# rainfall            False
# Crop                False
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value               False
# Flag                False
# Flag Description    False
# Note                 True
# dtype: bool

# %%
df3.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested            0113  Rice
# 1  Crops and livestock products  ...           Yield            0113  Rice
# 2  Crops and livestock products  ...      Production            0113  Rice
# 3  Crops and livestock products  ...  Area harvested            0113  Rice
# 4  Crops and livestock products  ...           Yield            0113  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df3.isnull().any()
# Out:
# N                   False
# P                   False
# K                   False
# temperature         False
# humidity            False
# ph                  False
# rainfall            False
# Crop                False
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value               False
# Flag                False
# Flag Description    False
# Note                 True
# dtype: bool

# %%
df3.isna().any()
# Out:
# N                   False
# P                   False
# K                   False
# temperature         False
# humidity            False
# ph                  False
# rainfall            False
# Crop                False
# Domain Code         False
# Domain              False
# Area Code (M49)     False
# Area                False
# Element Code        False
# Element             False
# Item Code (CPC)     False
# Item                False
# Year Code           False
# Year                False
# Unit                False
# Value               False
# Flag                False
# Flag Description    False
# Note                 True
# dtype: bool

# %%
df3.dtypes
# Out:
# N                     int64
# P                     int64
# K                     int64
# temperature         float64
# humidity            float64
# ph                  float64
# rainfall            float64
# Crop                 object
# Domain Code          object
# Domain               object
# Area Code (M49)       int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code (CPC)      object
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# Note                 object
# dtype: object

# %%
df3.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested            0113  Rice
# 1  Crops and livestock products  ...           Yield            0113  Rice
# 2  Crops and livestock products  ...      Production            0113  Rice
# 3  Crops and livestock products  ...  Area harvested            0113  Rice
# 4  Crops and livestock products  ...           Yield            0113  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
len(df3)
# Out:
# 114000

# %%
df3.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested            0113  Rice
# 1  Crops and livestock products  ...           Yield            0113  Rice
# 2  Crops and livestock products  ...      Production            0113  Rice
# 3  Crops and livestock products  ...  Area harvested            0113  Rice
# 4  Crops and livestock products  ...           Yield            0113  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df3.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'Crop',
#        'Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
df3.dtypes
# Out:
# N                     int64
# P                     int64
# K                     int64
# temperature         float64
# humidity            float64
# ph                  float64
# rainfall            float64
# Crop                 object
# Domain Code          object
# Domain               object
# Area Code (M49)       int64
# Area                 object
# Element Code          int64
# Element              object
# Item Code (CPC)      object
# Item                 object
# Year Code             int64
# Year                  int64
# Unit                 object
# Value               float64
# Flag                 object
# Flag Description     object
# Note                 object
# dtype: object

# %%
df3.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested            0113  Rice
# 1  Crops and livestock products  ...           Yield            0113  Rice
# 2  Crops and livestock products  ...      Production            0113  Rice
# 3  Crops and livestock products  ...  Area harvested            0113  Rice
# 4  Crops and livestock products  ...           Yield            0113  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df3.columns
# Out:
# Index(['N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'Crop',
#        'Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
#        'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit',
#        'Value', 'Flag', 'Flag Description', 'Note'],
#       dtype='object')

# %%
df3.to_csv("final.csv", index=False)

# %%
df4=pd.read_csv('final.csv')
# Out:
# C:\Users\skart\AppData\Local\Temp\ipykernel_17356\701585182.py:1: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df4=pd.read_csv('final.csv')

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop Domain Code  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice         QCL
#
#                          Domain  ...         Element Item Code (CPC)  Item  \
# 0  Crops and livestock products  ...  Area harvested           113.0  Rice
# 1  Crops and livestock products  ...           Yield           113.0  Rice
# 2  Crops and livestock products  ...      Production           113.0  Rice
# 3  Crops and livestock products  ...  Area harvested           113.0  Rice
# 4  Crops and livestock products  ...           Yield           113.0  Rice
#
#   Year Code  Year   Unit        Value  Flag Flag Description  Note
# 0      2004  2004     ha   41906700.0     A  Official figure   NaN
# 1      2004  2004  kg/ha       2975.6     A  Official figure   NaN
# 2      2004  2004      t  124697104.0     A  Official figure   NaN
# 3      2005  2005     ha   43659800.0     A  Official figure   NaN
# 4      2005  2005  kg/ha       3153.7     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df4 = df4[df4['Element'] == 'Production']

# %%
df4.head()
# Out:
#      N   P   K  temperature   humidity        ph    rainfall  Crop  \
# 2   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 5   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 8   90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 11  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 14  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
#
#    Domain Code                        Domain  ...     Element Item Code (CPC)  \
# 2          QCL  Crops and livestock products  ...  Production           113.0
# 5          QCL  Crops and livestock products  ...  Production           113.0
# 8          QCL  Crops and livestock products  ...  Production           113.0
# 11         QCL  Crops and livestock products  ...  Production           113.0
# 14         QCL  Crops and livestock products  ...  Production           113.0
#
#     Item Year Code  Year Unit        Value  Flag Flag Description  Note
# 2   Rice      2004  2004    t  124697104.0     A  Official figure   NaN
# 5   Rice      2005  2005    t  137690096.0     A  Official figure   NaN
# 8   Rice      2006  2006    t  139136992.0     A  Official figure   NaN
# 11  Rice      2007  2007    t  144570000.0     A  Official figure   NaN
# 14  Rice      2008  2008    t  148036000.0     A  Official figure   NaN
#
# [5 rows x 23 columns]

# %%
df4=df4.drop(columns=['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code',
       'Element', 'Item Code (CPC)', 'Item', 'Year Code','Unit', 'Flag', 'Flag Description', 'Note'])

# %%
df4.head()
# Out:
#      N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 2   90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 5   90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 8   90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2006
# 11  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2007
# 14  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2008
#
#           Value
# 2   124697104.0
# 5   137690096.0
# 8   139136992.0
# 11  144570000.0
# 14  148036000.0

# %%
df4.isnull().any()
# Out:
# N              False
# P              False
# K              False
# temperature    False
# humidity       False
# ph             False
# rainfall       False
# Crop           False
# Year           False
# Value          False
# dtype: bool

# %%
df4[df4.duplicated()]
# Out:
#          N   P   K  temperature   humidity        ph   rainfall       Crop  \
# 60005  115  17  55    27.578269  94.118782  6.776533  28.082532  muskmelon
# 60011  115  17  55    27.578269  94.118782  6.776533  28.082532  muskmelon
# 60017  115  17  55    27.578269  94.118782  6.776533  28.082532  muskmelon
# 60023  115  17  55    27.578269  94.118782  6.776533  28.082532  muskmelon
# 60029  115  17  55    27.578269  94.118782  6.776533  28.082532  muskmelon
# ...    ...  ..  ..          ...        ...       ...        ...        ...
# 71975  106  16  54    28.960179  91.695322  6.585873  24.745820  muskmelon
# 71981  106  16  54    28.960179  91.695322  6.585873  24.745820  muskmelon
# 71987  106  16  54    28.960179  91.695322  6.585873  24.745820  muskmelon
# 71993  106  16  54    28.960179  91.695322  6.585873  24.745820  muskmelon
# 71999  106  16  54    28.960179  91.695322  6.585873  24.745820  muskmelon
#
#        Year       Value
# 60005  2004   758528.68
# 60011  2005   792199.13
# 60017  2006   819427.00
# 60023  2007   847701.58
# 60029  2008   876007.99
# ...     ...         ...
# 71975  2019  1266000.00
# 71981  2020  1368000.00
# 71987  2021  1478000.00
# 71993  2022  1498000.00
# 71999  2023  1498000.00
#
# [2000 rows x 10 columns]

# %%
df4=df4.drop_duplicates().reset_index(drop=True)

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2006
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2007
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2008
#
#          Value
# 0  124697104.0
# 1  137690096.0
# 2  139136992.0
# 3  144570000.0
# 4  148036000.0

# %%
df4['Crop'].value_counts()
# Out:
# Crop
# rice          2000
# maize         2000
# chickpea      2000
# pigeonpeas    2000
# mothbeans     2000
# lentil        2000
# banana        2000
# mango         2000
# grapes        2000
# watermelon    2000
# muskmelon     2000
# apple         2000
# orange        2000
# papaya        2000
# coconut       2000
# cotton        2000
# jute          2000
# coffee        2000
# Name: count, dtype: int64

# %%
len(df4['Crop'].unique())
# Out:
# 18

# %%
df4.dtypes
# Out:
# N                int64
# P                int64
# K                int64
# temperature    float64
# humidity       float64
# ph             float64
# rainfall       float64
# Crop            object
# Year             int64
# Value          float64
# dtype: object

# %%
df4.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall  Crop  Year  \
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2004
# 1  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2005
# 2  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2006
# 3  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2007
# 4  90  42  43    20.879744  82.002744  6.502985  202.935536  rice  2008
#
#          Value
# 0  124697104.0
# 1  137690096.0
# 2  139136992.0
# 3  144570000.0
# 4  148036000.0

# %%
numeric_cols = df4.select_dtypes(include=[np.number]).columns
outlier_summary = {}
for col in numeric_cols:
    Q1 = df4[col].quantile(0.25)
    Q3 = df4[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = df4[(df4[col] < lower_bound) | (df4[col] > upper_bound)][col]
    outlier_summary[col] = {
        "Lower Bound": lower_bound,
        "Upper Bound": upper_bound,
        "Outlier Count": outliers.shape[0],
        "Outlier Values": outliers.values
    }
for col, info in outlier_summary.items():
    print("\nColumn:", col)
    print("Lower Bound:", info["Lower Bound"])
    print("Upper Bound:", info["Upper Bound"])
    print("Outliers:", info["Outlier Values"])
    print("Count:", info["Outlier Count"])
# Out:
# Column: N
# Lower Bound: -76.5
# Upper Bound: 191.5
# Outliers: []
# Count: 0
#
# Column: P
# Lower Bound: -34.125
#  280.4044392 280.4044392 280.4044392 280.4044392 290.6793783 290.6793783
#  290.6793783 290.6793783 290.6793783 290.6793783 290.6793783 290.6793783
#  290.6793783 290.6793783 290.6793783 290.6793783 290.6793783 290.6793783
#  290.6793783 290.6793783 290.6793783 290.6793783 290.6793783 290.6793783
#  295.9248796 295.9248796 295.9248796 295.9248796 295.9248796 295.9248796
#  295.9248796 295.9248796 295.9248796 295.9248796 295.9248796 295.9248796
#  295.9248796 295.9248796 295.9248796 295.9248796 295.9248796 295.9248796
#  295.9248796 295.9248796 287.5766935 287.5766935 287.5766935 287.5766935
#  287.5766935 287.5766935 287.5766935 287.5766935 287.5766935 287.5766935
#  287.5766935 287.5766935 287.5766935 287.5766935 287.5766935 287.5766935
#  287.5766935 287.5766935 287.5766935 287.5766935]
# Count: 580
#
# Column: Year
# Lower Bound: 1994.5
# Upper Bound: 2032.5
# Outliers: []
# Count: 0
#
# Column: Value
# Lower Bound: -17561375.0
# Upper Bound: 33263625.0
# Outliers: [1.24697104e+08 1.37690096e+08 1.39136992e+08 ... 3.66140000e+07
#  3.45280000e+07 3.66140000e+07]
# Count: 2400

# %%
df4_clean = df4.copy()

for col in numeric_cols:
    Q1 = df4_clean[col].quantile(0.25)
    Q3 = df4_clean[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df4_clean = df4_clean[(df4_clean[col] >= lower_bound) & (df4_clean[col] <= upper_bound)]

# %%
df4_clean.head()
# Out:
#        N   P   K  temperature   humidity        ph   rainfall   Crop  Year  \
# 2000  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2004
# 2001  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2005
# 2002  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2006
# 2003  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2007
# 2004  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2008
#
#            Value
# 2000  14172000.0
# 2001  14709900.0
# 2002  15097000.0
# 2003  18955400.0
# 2004  19731400.0

# %%
len(df4_clean)
# Out:
# 27220

# %%
df4_clean=df4_clean.reset_index(drop=True)

# %%
df4_clean.head()
# Out:
#     N   P   K  temperature   humidity        ph   rainfall   Crop  Year  \
# 0  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2004
# 1  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2005
# 2  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2006
# 3  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2007
# 4  71  54  16      22.6136  63.690706  5.749914  87.759539  maize  2008
#
#         Value
# 0  14172000.0
# 1  14709900.0
# 2  15097000.0
# 3  18955400.0
# 4  19731400.0

# %%
df4_clean[df4_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [N, P, K, temperature, humidity, ph, rainfall, Crop, Year, Value]
# Index: []

# %%
len(df4_clean)
# Out:
# 27220

# %%
df4_clean['Crop'].value_counts()
# Out:
# Crop
# maize         2000
# banana        2000
# lentil        2000
# coconut       2000
# cotton        2000
# muskmelon     2000
# watermelon    2000
# jute          2000
# coffee        2000
# mango         1880
# chickpea      1740
# pigeonpeas    1740
# orange        1560
# papaya        1220
# mothbeans     1080
# Name: count, dtype: int64
