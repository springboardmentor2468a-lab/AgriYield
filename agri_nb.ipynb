# %% [markdown]
# <h1 align="center"><b>AgriYield Predictor</b></h1>
# <h2 align="center"> - Manju Varshikha S </h2>
# <h3 align="center">The project aims to assist farmers and agricultural planners in optimizing crop production.</h3>

# %% [markdown]
# ## 1. Import Libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

print("Libraries loaded successfully.")
# Out:
# Libraries loaded successfully.

# %% [markdown]
# ## 2. Load Datasets

# %%
df_faostat = pd.read_csv("data/FAOSTAT_data_en_11-18-2025.csv")
df_crop_labels = pd.read_csv("data/Crop_recommendation.csv")

print("\nFAOSTAT Dataset:")
display(df_faostat.head())
print("Shape:", df_faostat.shape)

print("\nCrop Label Dataset:")
display(df_crop_labels.head())
print("Shape:", df_crop_labels.shape)
# Out:
# FAOSTAT Dataset:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)  \
# 0          5312  Area harvested           01654
# 1          5412           Yield           01654
# 2          5510      Production           01654
# 3          5312  Area harvested           01654
# 4          5412           Yield           01654
#
#                                                 Item  Year Code  Year   Unit  \
# 0  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005     ha
# 1  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005  kg/ha
# 2  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005      t
# 3  Anise, badian, coriander, cumin, caraway, fenn...       2006  2006     ha
# 4  Anise, badian, coriander, cumin, caraway, fenn...       2006  2006  kg/ha
#
#       Value Flag Flag Description Note
# 0  446931.0    A  Official figure  NaN
# 1     584.4    A  Official figure  NaN
# 2  261170.0    A  Official figure  NaN
# 3  473089.0    A  Official figure  NaN
# 4     568.1    A  Official figure  NaN
# Shape: (4996, 15)
#
# Crop Label Dataset:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice
# Shape: (2200, 8)

# %% [markdown]
# ## 3. Split Multi-Value Items into Individual Crops
#
# Some items in `FAOSTAT.csv` dataset contain **multiple crops separated by commas**.
# We split these into individual rows for accurate merging.

# %%
df_faostat["crop_list"] = df_faostat["Item"].astype(str).str.split(",")
df_faostat_exploded = df_faostat.explode("crop_list").reset_index(drop=True)
df_faostat_exploded["crop_clean"] = df_faostat_exploded["crop_list"].str.lower().str.strip()

print("\nExploded FAOSTAT Dataset:")
display(df_faostat_exploded.head())
print("Shape:", df_faostat_exploded.shape)
# Out:
# Exploded FAOSTAT Dataset:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)  \
# 0          5312  Area harvested           01654
# 1          5312  Area harvested           01654
# 2          5312  Area harvested           01654
# 3          5312  Area harvested           01654
# 4          5312  Area harvested           01654
#
#                                                 Item  Year Code  Year Unit  \
# 0  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005   ha
# 1  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005   ha
# 2  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005   ha
# 3  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005   ha
# 4  Anise, badian, coriander, cumin, caraway, fenn...       2005  2005   ha
#
#       Value Flag Flag Description Note   crop_list crop_clean
# 0  446931.0    A  Official figure  NaN       Anise      anise
# 1  446931.0    A  Official figure  NaN      badian     badian
# 2  446931.0    A  Official figure  NaN   coriander  coriander
# 3  446931.0    A  Official figure  NaN       cumin      cumin
# 4  446931.0    A  Official figure  NaN     caraway    caraway
# Shape: (7662, 17)

# %% [markdown]
# ## 4. Clean Crop Labels
#
# We standardize the labels in `CropLabels.csv` to lowercase and strip whitespace.
# This ensures a **consistent merge** with `FAOSTAT.csv`.

# %%
df_crop_labels["label_clean"] = df_crop_labels["label"].astype(str).str.lower().str.strip()

print("\nCleaned Crop Label Dataset:")
display(df_crop_labels[["label", "label_clean"]].head())
# Out:
# Cleaned Crop Label Dataset:
#   label label_clean
# 0  rice        rice
# 1  rice        rice
# 2  rice        rice
# 3  rice        rice
# 4  rice        rice

# %% [markdown]
# ## 5. Merge Datasets on Cleaned Crop Names
#
# Perform an **inner merge** to combine FAOSTAT and Crop Label data based on `crop_clean` and `label_clean`.

# %%
df_merged = pd.merge(
    df_faostat_exploded,
    df_crop_labels,
    left_on="crop_clean",
    right_on="label_clean",
    how="inner"
)

print("\nMerged Dataset:")
display(df_merged.head())
print("Shape:", df_merged.shape)
print("Columns:", df_merged.columns.tolist())
# Out:
# Merged Dataset:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)           Item  Year Code  \
# 0          5312  Area harvested           01610  Coffee, green       2005
# 1          5312  Area harvested           01610  Coffee, green       2005
# 2          5312  Area harvested           01610  Coffee, green       2005
# 3          5312  Area harvested           01610  Coffee, green       2005
# 4          5312  Area harvested           01610  Coffee, green       2005
#
#    Year  ... crop_clean    N   P   K temperature   humidity        ph  \
# 0  2005  ...     coffee   91  21  26   26.333780  57.364700  7.261314
# 1  2005  ...     coffee  107  21  26   26.452885  55.322227  7.235070
# 2  2005  ...     coffee   83  38  35   25.708227  52.886671  7.189156
# 3  2005  ...     coffee  108  24  31   24.128325  56.181077  6.431900
# 4  2005  ...     coffee  116  28  34   23.443723  60.395233  6.423211
#
#      rainfall   label  label_clean
# 0  191.654941  coffee       coffee
# 1  144.686134  coffee       coffee
# 2  136.732509  coffee       coffee
# 3  147.275782  coffee       coffee
# 4  122.210325  coffee       coffee
#
# [5 rows x 26 columns]
# Shape: (22800, 26)
# Columns: ['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code', 'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Year', 'Unit', 'Value', 'Flag', 'Flag Description', 'Note', 'crop_list', 'crop_clean', 'N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label', 'label_clean']

# %% [markdown]
# ## 6. Null Value Analysis
#
# Check for missing values per column **before cleaning**.

# %%
print("\nNull Values per Column:")
print(df_merged.isnull().sum())
# Out:
# Null Values per Column:
# Domain Code             0
# Domain                  0
# Area Code (M49)         0
# Area                    0
# Element Code            0
# Element                 0
# Item Code (CPC)         0
# Item                    0
# Year Code               0
# Year                    0
# Unit                    0
# Value                   0
# Flag                    0
# Flag Description        0
# Note                22800
# crop_list               0
# crop_clean              0
# N                       0
# P                       0
# K                       0
# temperature             0
# humidity                0
# ph                      0
# rainfall                0
# label                   0
# label_clean             0
# dtype: int64

# %% [markdown]
# ## 7. Duplicate Analysis
#
# Check for **exact duplicates** and **logical duplicates** based on key columns: `Area`, `Year`, `crop_clean`.

# %%
print("\nExact Duplicates:", df_merged.duplicated().sum())

key_columns = ["Area", "Year", "crop_clean"]
existing_keys = [c for c in key_columns if c in df_merged.columns]

if existing_keys:
    logical_duplicates = df_merged.duplicated(subset=existing_keys).sum()
    print("Logical Key Duplicates:", logical_duplicates)
else:
    print("No suitable key columns for logical duplicate check.")
# Out:
# Exact Duplicates: 0
# Logical Key Duplicates: 22724

# %% [markdown]
# ## 8. Clean Missing Values & Deduplicate
#
# - Remove **duplicate rows**.
# - Fill missing numeric values with **median** of each column.

# %%
df_cleaned = df_merged.drop_duplicates().copy()

numeric_columns = df_cleaned.select_dtypes(include=[np.number]).columns.tolist()
for col in numeric_columns:
    if df_cleaned[col].isnull().any():
        df_cleaned[col] = df_cleaned[col].fillna(df_cleaned[col].median())

print("\nDataset after NA handling and deduplication:")
display(df_cleaned.head())
print("Shape:", df_cleaned.shape)
# Out:
# Dataset after NA handling and deduplication:
#   Domain Code                        Domain  Area Code (M49)   Area  \
# 0         QCL  Crops and livestock products              356  India
# 1         QCL  Crops and livestock products              356  India
# 2         QCL  Crops and livestock products              356  India
# 3         QCL  Crops and livestock products              356  India
# 4         QCL  Crops and livestock products              356  India
#
#    Element Code         Element Item Code (CPC)           Item  Year Code  \
# 0          5312  Area harvested           01610  Coffee, green       2005
# 1          5312  Area harvested           01610  Coffee, green       2005
# 2          5312  Area harvested           01610  Coffee, green       2005
# 3          5312  Area harvested           01610  Coffee, green       2005
# 4          5312  Area harvested           01610  Coffee, green       2005
#
#    Year  ... crop_clean    N   P   K temperature   humidity        ph  \
# 0  2005  ...     coffee   91  21  26   26.333780  57.364700  7.261314
# 1  2005  ...     coffee  107  21  26   26.452885  55.322227  7.235070
# 2  2005  ...     coffee   83  38  35   25.708227  52.886671  7.189156
# 3  2005  ...     coffee  108  24  31   24.128325  56.181077  6.431900
# 4  2005  ...     coffee  116  28  34   23.443723  60.395233  6.423211
#
#      rainfall   label  label_clean
# 0  191.654941  coffee       coffee
# 1  144.686134  coffee       coffee
# 2  136.732509  coffee       coffee
# 3  147.275782  coffee       coffee
# 4  122.210325  coffee       coffee
#
# [5 rows x 26 columns]
# Shape: (22800, 26)

# %% [markdown]
# ## 9. Outlier Visualization
#
# We visualize numeric columns using **boxplots** before and after cleaning.

# %%
# Before Cleaning
print("\nBoxplots Before Cleaning (Original Data):")
for col in numeric_columns:
    plt.figure(figsize=(6, 3))
    plt.boxplot(df_merged[col].dropna())
    plt.title(f"Boxplot Before Cleaning: {col}")
    plt.ylabel(col)
    plt.show()

# After Cleaning
print("\nBoxplots After Cleaning (NA Handling & Deduplication):")
for col in numeric_columns:
    plt.figure(figsize=(6, 3))
    plt.boxplot(df_cleaned[col].dropna())
    plt.title(f"Boxplot After Cleaning: {col}")
    plt.ylabel(col)
    plt.show()
# Out:
# Boxplots Before Cleaning (Original Data):
# Boxplots After Cleaning (NA Handling & Deduplication):

# %%
df_merged.columns.tolist()
# Out:
# ['Domain Code',
#  'Domain',
#  'Area Code (M49)',
#  'Area',
#  'Element Code',
#  'Element',
#  'Item Code (CPC)',
#  'Item',
#  'Year Code',
#  'Year',
#  'Unit',
#  'Value',
#  'Flag',
#  'Flag Description',
#  'Note',
#  'crop_list',
#  'crop_clean',
#  'N',
#  'P',
#  'K',
#  'temperature',
#  'humidity',
#  'ph',
#  'rainfall',
#  'label',
#  'label_clean']

# %% [markdown]
# Drop Unwanted Columns

# %%
cols_to_drop = [
    "Domain Code", "Domain", "Area Code (M49)", "Area",
    "Element Code", "Element",
    "Item Code (CPC)", "Item",
    "Year Code", "Unit",
    "Flag", "Flag Description", "Note",
    "crop_list", "label_clean"
]

cols_to_drop = [c for c in cols_to_drop if c in df_merged.columns]

df_reduced = df_merged.drop(columns=cols_to_drop)

print("Columns dropped:", cols_to_drop)
print("Shape after dropping:", df_reduced.shape)
display(df_reduced.head())
# Out:
# Columns dropped: ['Domain Code', 'Domain', 'Area Code (M49)', 'Area', 'Element Code', 'Element', 'Item Code (CPC)', 'Item', 'Year Code', 'Unit', 'Flag', 'Flag Description', 'Note', 'crop_list', 'label_clean']
# Shape after dropping: (22800, 11)
#    Year     Value crop_clean    N   P   K  temperature   humidity        ph  \
# 0  2005  333338.0     coffee   91  21  26    26.333780  57.364700  7.261314
# 1  2005  333338.0     coffee  107  21  26    26.452885  55.322227  7.235070
# 2  2005  333338.0     coffee   83  38  35    25.708227  52.886671  7.189156
# 3  2005  333338.0     coffee  108  24  31    24.128325  56.181077  6.431900
# 4  2005  333338.0     coffee  116  28  34    23.443723  60.395233  6.423211
#
#      rainfall   label
# 0  191.654941  coffee
# 1  144.686134  coffee
# 2  136.732509  coffee
# 3  147.275782  coffee
# 4  122.210325  coffee

# %% [markdown]
# ## EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.style.use("default")
sns.set_palette("deep")

# -----------------------------
# Dataset Overview
# -----------------------------
print("Shape:", df_reduced.shape)
print("\nColumns:", df_reduced.columns.tolist())
display(df_reduced.head())

# -----------------------------
# Boxplots (Outlier Visualization)
# -----------------------------
numeric_cols = df_reduced.select_dtypes(include='number').columns.tolist()
for col in numeric_cols:
    plt.figure(figsize=(5, 3))
    sns.boxplot(x=df_reduced[col])
    plt.title(f"Boxplot: {col}")
    plt.show()


# -----------------------------
# Correlation Heatmap
# -----------------------------
plt.figure(figsize=(10, 7))
corr = df_reduced[numeric_cols].corr()
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()


# -----------------------------
# Year-wise Trend of Yield/Value
# -----------------------------
if "Year" in df_reduced.columns:
    plt.figure(figsize=(8, 4))
    yearly = df_reduced.groupby("Year")["Value"].mean()
    plt.plot(yearly.index, yearly.values)
    plt.title("Average Yield Value Over Years")
    plt.xlabel("Year")
    plt.ylabel("Yield Value")
    plt.grid(True)
    plt.show()


# -----------------------------
# Crop-wise Yield Comparison
# -----------------------------
plt.figure(figsize=(10,5))
top_crops = (
    df_reduced.groupby("crop_clean")["Value"]
    .mean()
    .sort_values(ascending=False)
    .head(10)
)

sns.barplot(x=top_crops.index, y=top_crops.values)
plt.title("Top 10 Crops by Average Yield Value")
plt.xticks(rotation=45)
plt.show()
# Out:
# Shape: (22800, 11)
#
# Columns: ['Year', 'Value', 'crop_clean', 'N', 'P', 'K', 'temperature', 'humidity', 'ph', 'rainfall', 'label']
#    Year     Value crop_clean    N   P   K  temperature   humidity        ph  \
# 0  2005  333338.0     coffee   91  21  26    26.333780  57.364700  7.261314
# 1  2005  333338.0     coffee  107  21  26    26.452885  55.322227  7.235070
# 2  2005  333338.0     coffee   83  38  35    25.708227  52.886671  7.189156
# 3  2005  333338.0     coffee  108  24  31    24.128325  56.181077  6.431900
# 4  2005  333338.0     coffee  116  28  34    23.443723  60.395233  6.423211
#
#      rainfall   label
# 0  191.654941  coffee
# 1  144.686134  coffee
# 2  136.732509  coffee
# 3  147.275782  coffee
# 4  122.210325  coffee
